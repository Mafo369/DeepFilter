# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sp
import scipy.io.wavfile as wav



plt.rcParams['figure.figsize'] = [20, 10]

# %%
mat = sp.loadmat('data/S1.mat')
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Thu Jun 30 21:37:43 2016', '__version__': '1.0', '__globals__': [], 'fs': array([[1000]], dtype=uint16), 'x': array([[ 48.47592968],
#        [ 29.00454208],
#        [-39.06920522],
#        ...,
#        [-33.52828097],
#        [-17.85867046],
#        [ 12.91995748]])}

# %%
x = np.array(mat['x'])
print(x.shape)
fs = mat['fs'][0][0]
# Out:
# (60000, 1)

# %%
sp.wavfile.write("test.wav", fs, x.astype(np.int16))

# %%
plt.plot(np.arange(len(x))/fs, x)

# %%
x = np.array_split(x, int(len(x) / 512))
print(len(x))
# Out:
# 117

# %%
# Out:
# (117,)
# <ipython-input-43-b08346e7a651>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x = np.array(x)

# %%
mat1 = sp.loadmat('data/S2.mat')
print(mat1)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Thu Jun 30 21:37:43 2016', '__version__': '1.0', '__globals__': [], 'fs': array([[1000]], dtype=uint16), 'x': array([[ -9.00835158],
#        [-18.16260495],
#        [-18.45882668],
#        ...,
#        [ -3.2173199 ],
#        [ 31.80379943],
#        [ -3.87379592]])}

# %%
mat2 = sp.loadmat('data/S2_Clean.mat')
print(mat2['PCG'].shape)
# Out:
# (45001, 1)
